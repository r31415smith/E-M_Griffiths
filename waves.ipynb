# %% [markdown]
# ### Practice visualizing waves
# This brief simulation helps us think about how each variable in a function describing a wave affects the properties and propagation in time of that wave.

# %%
# import libraries
import numpy as np
import matplotlib.pyplot as plt
from scipy import interpolate
# %matplotlib inline

# %%
# define the spatial dimention of the wave
x = np.arange(0,1000,1)

# %% [markdown]
# Things to try in the following widget:
# * modify amplitude and k. Note how the waveform changes, see if it makes sense to you based on the equation of the wave and how k is related to lambda.
# * try changing omega: before you do, try scanning time (slowly!) then bring the time slider bar all the way back. Note the speed of the wave. Then change omega, and try scanning the time slider at the same rate. What changed? Does changing k also change the speed of the wave?
# * Try adding a phase shift slider bar into the widget below. What affect does including a positive or negative phase have?
# * Create a new widget that defines a wave as a complex exponential. Then plot the real or imaginary part.

# %%
from IPython.html.widgets import interact

def plot_sine(amplitude=1.0, k = 1.0, omega=1.0, t = 1.0):
    plt.ylim(-1.0, 1.0);
    x = np.linspace(0, 10, 1000)
    plt.plot(x, amplitude*np.sin(x*k-omega*t));
    plt.xlabel('location (m)',fontsize=15)
    plt.ylabel('electric field (a.u.)',fontsize=15)

interact(plot_sine, amplitude=(0.0, 1.0),k=(0.0, 5.0),omega=(0.5, 10.0),t=(0.0, 5.0));
